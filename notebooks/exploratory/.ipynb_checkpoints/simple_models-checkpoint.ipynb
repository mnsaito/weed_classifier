# %%
# Standard Imports
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import random
import os
from PIL import Image, ImageStat

# Modeling Imports
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import Sequential
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import (Dense, Flatten, Input, Conv2D, 
                                     MaxPooling2D)

from sklearn.metrics import (confusion_matrix, ConfusionMatrixDisplay, 
                             accuracy_score, precision_score)
from sklearn.utils import class_weight

# Lime Imports
# %load_ext autoreload
# %autoreload 2
import lime
from lime import lime_image
from skimage.segmentation import mark_boundaries

import sys
sys.path.append(os.path.join(os.pardir, os.pardir, 'src'))
import functions as fx

# %%
train_path = os.path.join(os.pardir, os.pardir, 'data', 'train')

# %%
train_datagen = ImageDataGenerator(rescale = 1./255.,
                                   rotation_range = 30, zoom_range = 0.3,
                                   width_shift_range = 0.2, height_shift_range = 0.2,
                                   horizontal_flip = True, brightness_range = [0.5, 1.5], 
                                   validation_split = 0.1)
val_datagen = ImageDataGenerator(rescale = 1./255, validation_split = 0.1)
train_generator = train_datagen.flow_from_directory(
    train_path, seed = 55, target_size = (256, 256), 
    batch_size = 64, class_mode = 'binary', 
    classes = ['perennials', 'weeds'], subset = 'training')
val_generator = val_datagen.flow_from_directory(
    train_path, seed = 55, target_size = (256, 256),
    batch_size = 64, class_mode = 'binary', 
    classes = ['perennials', 'weeds'], subset = 'validation')
# Out:
# Found 4698 images belonging to 2 classes.
# Found 521 images belonging to 2 classes.

# %%
# Calculate weights to balance perennial and weed data in training set
class_weights = class_weight.compute_class_weight(
    class_weight = 'balanced', classes = np.unique(train_generator.classes), 
    y = train_generator.classes)
train_class_weights = dict(enumerate(class_weights))

# Stop training if loss does not decrease in 5 epochs
early_stop_loss = EarlyStopping(monitor = 'loss', patience = 5, restore_best_weights = True)

# %%
def baseline_model(image):
    layers = [
        Input(image.shape),
        Flatten(),
        Dense(128, activation = 'relu'),
        Dense(1, activation = 'sigmoid')
    ]
    model = Sequential(layers)
    model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics=['accuracy', 'Precision'])
    return model

# %%
base_model = baseline_model(train_generator[0][0][0])
base_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 196608)            0
# _________________________________________________________________
# dense (Dense)                (None, 128)               25165952
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 25,166,081
# Trainable params: 25,166,081
# Non-trainable params: 0
# _________________________________________________________________

# %%
base_result = base_model.fit(train_generator, epochs = 10, validation_data=val_generator,
                             class_weight = train_class_weights, callbacks = [early_stop_loss])
# Out:
# Epoch 1/10
# 74/74 [==============================] - 72s 972ms/step - loss: 9.8990 - accuracy: 0.5015 - precision: 0.5142 - val_loss: 0.6931 - val_accuracy: 0.5144 - val_precision: 0.5144
# Epoch 2/10
# 74/74 [==============================] - 67s 906ms/step - loss: 0.7177 - accuracy: 0.5151 - precision: 0.5152 - val_loss: 0.6931 - val_accuracy: 0.5144 - val_precision: 0.5144
# Epoch 3/10
# 74/74 [==============================] - 69s 926ms/step - loss: 0.6932 - accuracy: 0.4851 - precision: 0.5005 - val_loss: 0.6931 - val_accuracy: 0.5144 - val_precision: 0.5144
# Epoch 4/10
# 74/74 [==============================] - 68s 915ms/step - loss: 0.6932 - accuracy: 0.5153 - precision: 0.5153 - val_loss: 0.6931 - val_accuracy: 0.5144 - val_precision: 0.5144
# Epoch 5/10
# 74/74 [==============================] - 68s 916ms/step - loss: 0.6932 - accuracy: 0.5153 - precision: 0.5153 - val_loss: 0.6931 - val_accuracy: 0.5144 - val_precision: 0.5144
# Epoch 6/10
# 74/74 [==============================] - 66s 898ms/step - loss: 0.6932 - accuracy: 0.5153 - precision: 0.5153 - val_loss: 0.6931 - val_accuracy: 0.5144 - val_precision: 0.5144
# Epoch 7/10
# 74/74 [==============================] - 66s 892ms/step - loss: 0.6932 - accuracy: 0.5153 - precision: 0.5153 - val_loss: 0.6931 - val_accuracy: 0.5144 - val_precision: 0.5144
# Epoch 8/10
# 74/74 [==============================] - 66s 895ms/step - loss: 0.6932 - accuracy: 0.5153 - precision: 0.5153 - val_loss: 0.6931 - val_accuracy: 0.5144 - val_precision: 0.5144
# Epoch 9/10
# 74/74 [==============================] - 66s 892ms/step - loss: 0.6932 - accuracy: 0.5123 - precision: 0.5142 - val_loss: 0.6931 - val_accuracy: 0.5144 - val_precision: 0.5144
# Epoch 10/10
# 74/74 [==============================] - 66s 893ms/step - loss: 0.6932 - accuracy: 0.4953 - precision: 0.5085 - val_loss: 0.6931 - val_accuracy: 0.5144 - val_precision: 0.5144

# %%
fx.visualize_training_results(base_result)

# %%
fx.create_confusion_matrix(base_model, val_generator)

# %%
fx.get_metrics(base_model, val_generator)
# Out:
# Accuracy: 0.5143953934740882
# Precision: 0.5143953934740882

# %%
fx.display_lime(base_model, val_generator)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=1000.0), HTML(value='')))

# %%
def baseline_cnn(image):
    layers = [
        Input(image.shape),
        Conv2D(32, (3,3), activation = 'relu'),
        Flatten(),
        Dense(128, activation = 'relu'),
        Dense(1, activation = 'sigmoid')
    ]
    model = Sequential(layers)
    model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics=['accuracy', 'Precision'])
    return model

# %%
base_cnn = baseline_cnn(train_generator[0][0][0])
base_cnn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 254, 254, 32)      896
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2064512)           0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               264257664
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 264,258,689
# Trainable params: 264,258,689
# Non-trainable params: 0
# _________________________________________________________________

# %%
cnn_result = base_cnn.fit(train_generator, epochs = 10, validation_data=val_generator,
                          class_weight = train_class_weights, callbacks = [early_stop_loss])
# Out:
# Epoch 1/10
# 74/74 [==============================] - 129s 2s/step - loss: 8.1355 - accuracy: 0.6588 - precision: 0.6727 - val_loss: 0.7713 - val_accuracy: 0.6276 - val_precision: 0.6201
# Epoch 2/10
# 74/74 [==============================] - 133s 2s/step - loss: 0.5710 - accuracy: 0.7309 - precision: 0.7308 - val_loss: 0.8445 - val_accuracy: 0.6334 - val_precision: 0.6271
# Epoch 3/10
# 74/74 [==============================] - 127s 2s/step - loss: 0.5727 - accuracy: 0.7309 - precision: 0.7320 - val_loss: 0.8119 - val_accuracy: 0.6046 - val_precision: 0.5917
# Epoch 4/10
# 74/74 [==============================] - 125s 2s/step - loss: 0.5403 - accuracy: 0.7407 - precision: 0.7365 - val_loss: 0.9008 - val_accuracy: 0.6718 - val_precision: 0.6887
# Epoch 5/10
# 74/74 [==============================] - 125s 2s/step - loss: 0.5190 - accuracy: 0.7652 - precision: 0.7647 - val_loss: 0.9021 - val_accuracy: 0.6814 - val_precision: 0.7024
# Epoch 6/10
# 74/74 [==============================] - 126s 2s/step - loss: 0.5250 - accuracy: 0.7599 - precision: 0.7509 - val_loss: 0.8424 - val_accuracy: 0.6392 - val_precision: 0.6227
# Epoch 7/10
# 74/74 [==============================] - 124s 2s/step - loss: 0.5109 - accuracy: 0.7646 - precision: 0.7577 - val_loss: 0.8617 - val_accuracy: 0.6871 - val_precision: 0.7059
# Epoch 8/10
# 74/74 [==============================] - 121s 2s/step - loss: 0.5362 - accuracy: 0.7518 - precision: 0.7489 - val_loss: 0.8613 - val_accuracy: 0.6948 - val_precision: 0.8187
# Epoch 9/10
# 74/74 [==============================] - 120s 2s/step - loss: 0.4975 - accuracy: 0.7642 - precision: 0.7604 - val_loss: 0.9827 - val_accuracy: 0.6852 - val_precision: 0.8291
# Epoch 10/10
# 74/74 [==============================] - 120s 2s/step - loss: 0.4734 - accuracy: 0.7846 - precision: 0.7725 - val_loss: 0.8524 - val_accuracy: 0.6929 - val_precision: 0.7308

# %%
fx.visualize_training_results(base_result)

# %%
fx.create_confusion_matrix(base_model, val_generator)

# %%
fx.get_metrics(base_model, val_generator)
# Out:
# Accuracy: 0.5182341650671785
# Precision: 0.5166340508806262

# %%
fx.display_lime(base_model, val_generator)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=1000.0), HTML(value='')))
